# %%
import pickle

# %%
a1 = [1, 2, 3, 4]

# %%
with open('var_a1.pkl','wb') as f:
    pickle.dump(a1,f)

# %%
with open('var_a1.pkl','rb') as f:
    a2 = pickle.load(f)
a2
# Out:
# [1, 2, 3, 4]

# %%
with open('voiture_model_X_test.pkl','rb') as f:
    y_test = pickle.load(f)
y_test
# Out:
#       annee  kilometrage  portes  puissance_fiscale  places  energie_Diesel  \
# 438    2012       113000       2                  7       5               0
# 1863   2021           10       4                  7       5               1
# 377    2017        78000       4                  6       5               1
# 1150   2006       150000       4                 19       5               0
# 360    2009       171000       4                 32       5               0
# ...     ...          ...     ...                ...     ...             ...
# 599    2019        31530       4                  6       5               0
# 1765   2020        20745       4                  5       5               0
# 301    2012        71400       4                  5       5               1
# 875    2015       112000       4                  5       5               1
# 1796   2020        66182       2                  5       2               1
#
#       energie_Essence  energie_Hybride  energie_Autres  energie_GPL ou GNL  \
# 438                 1                0               0                   0
# 1863                0                0               0                   0
# 377                 0                0               0                   0
# 1150                1                0               0                   0
# 360                 1                0               0                   0
# ...               ...              ...             ...                 ...
# 599                 1                0               0                   0
# 1765                1                0               0                   0
# 301                 0                0               0                   0
# 875                 0                0               0                   0
# 1796                0                0               0                   0
#
#       ...  marque_NISSAN  marque_HYUNDAI  marque_SUZUKI  marque_ALFA  \
# 438   ...              0               0              0            0
# 1863  ...              0               0              0            0
# 377   ...              0               0              0            0
# 1150  ...              0               0              0            0
# 360   ...              0               0              0            0
# ...   ...            ...             ...            ...          ...
# 599   ...              0               0              0            0
# 1765  ...              0               0              0            0
# 301   ...              0               0              0            0
# 875   ...              0               0              0            0
# 1796  ...              0               0              0            0
#
#       marque_VOLVO  marque_LAND  marque_CITROËN  marque_Mercedes-Benz  \
# 438              0            0               0                     0
# 1863             0            0               0                     0
# 377              0            0               0                     0
# 1150             0            0               0                     0
# 360              0            0               0                     0
# ...            ...          ...             ...                   ...
# 599              0            0               0                     0
# 1765             0            0               0                     0
# 301              0            0               0                     0
# 875              0            0               0                     0
# 1796             0            0               0                     0
#
#       marque_Ds  marque_Bmw
# 438           0           0
# 1863          0           0
# 377           0           0
# 1150          0           0
# 360           0           0
# ...         ...         ...
# 599           0           0
# 1765          0           0
# 301           0           0
# 875           0           0
# 1796          0           0
#
# [659 rows x 109 columns]

# %%
y_test.shape
# Out:
# (659, 109)
